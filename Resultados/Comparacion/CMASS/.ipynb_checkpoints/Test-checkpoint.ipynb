# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data=np.loadtxt('data.txt')

# %%
x=data[:,0]
y=data[:,1]
z=data[:,2]

# %%
r=x*x+y*y+z*z

# %%
plt.hist(np.sqrt(r),density=True);

# %%
r[0]
# Out:
# 1649174.35905793

# %%
plt.scatter(x[x<0],y[x<0],s=0.01)
