# %%
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x=np.arange(1.0,5.1,0.5)

# %%
y=np.loadtxt('C_Patchy.txt',usecols=0)

# %%
plt.figure(figsize=(8,6))
plt.plot(x,y,label='Patchy',marker='o',color='black')
plt.xlabel('\u03b2',fontsize=15)
plt.ylabel('C',fontsize=15)
plt.legend()
plt.savefig('C_Patchy.png')
